# %% [markdown]
# ## zeros -> zeros_like -> ones -> ones_like -> full -> full_like

# %%
import numpy as np

# normal array
a = [10, 30, 20]
b = [[14, 30, 20, 50],[10, 30, 20, 90]]
c = [
    #1st floor
    [[14, 30, 20, 50],
    [10, 30, 20, 90]],
    #2nd floor
    [[14, 30, 20, 50],
    [10, 30, 20, 90]],
    #3rd floor
    [[14, 30, 20, 50],
    [10, 30, 20, 90]],
]

# np.zeros

# inf = np.zeros((2,3), dtype=np.int16)   # dtype="int16" or dtype=np.int16 2 vabei lekha jay. 

# print(inf)
# print(type(inf))
# print(inf.shape)
# print(inf.size)
# print(inf.ndim)
# print(inf.dtype)

# np.zeros_like

# inf = np.zeros_like(c)

# print(inf)
# print(type(inf))
# print(inf.shape)
# print(inf.size)
# print(inf.ndim)
# print(inf.dtype)

# np.ones

# inf = np.ones((2,3), dtype='int16')

# print(inf)
# print(type(inf))
# print(inf.shape)
# print(inf.size)
# print(inf.ndim)
# print(inf.dtype)

# np.ones_like

# inf = np.ones_like(c)

# print(inf)
# print(type(inf))
# print(inf.shape)
# print(inf.size)
# print(inf.ndim)
# print(inf.dtype)

# np.full

# inf = np.full((4,4), 20, dtype='int16' )

# print(inf)
# print(type(inf))
# print(inf.shape)
# print(inf.size)
# print(inf.ndim)
# print(inf.dtype)

# np.full_like

# inf = np.full_like(c, np.inf, dtype=np.float16)

# print(inf)
# print(type(inf))
# print(inf.shape)
# print(inf.size)
# print(inf.ndim)
# print(inf.dtype)
