# %%
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 a=b
#
# NameError: name 'b' is not defined

# %%
try:
    a=b
except NameError as ex:
    print(ex)
# Out:
# name 'b' is not defined

# %%
result = 1/0
print(result)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 result = 1/0
#       2 print(result)
#
# ZeroDivisionError: division by zero

# %%
try:
    result = 1/0
    print(result)
except ZeroDivisionError as ex:
    print(ex)
# Out:
# division by zero

# %% [markdown]
# ## Or main class theke call korte pari. Corresponding error ek ektai dhorbe.

# %%
try:
    result = 1/0
    print(result)
except ZeroDivisionError as ex:
    print(ex)
except Exception as ex:    # Exeption part take last e rakha valo.
    print(ex)
# Out:
# division by zero
