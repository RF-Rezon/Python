# %%
import numpy as np

# list
new_array = [10, 30, 20]
arr = np.array(new_array)

# print(arr)
# print(type(arr))
# print(arr.shape)
# print(arr.size)
# print(arr.ndim)
# print(arr.dtype)

# tuple
# information = (10, 30, 20)
# print(type(information))
# information = np.array(information)
# print(information)
# print(type(information))
# print(information.shape)
# print(information.size)
# print(information.ndim)
# print(information.dtype)

# Set
# information = {10, 30, 20}
# print(type(information))
# information = np.array(list(information))    # Set ke direct NdArray banano jay na. List e convirt kroe neya lage. 
# print(information)
# print(type(information))
# print(information.shape)
# print(information.size)
# print(information.ndim)
# print(information.dtype)

# Dic
# information = {'a':10, 'b':30, 'c':20}
# print(type(information))
# informations = information.items();
# information = np.array(list(informations))     # Dic er khetreo list e convirt kora lage. 
# print(information)                             # UpCasting hoise. Values gulo int theke string e convirt hoya gese. 
# print(type(information))
# print(information.shape)
# print(information.size)
# print(information.ndim)
# print(information.dtype)
# Out:
# <class 'dict'>
# [['a' '10']
#  ['b' '30']
#  ['c' '20']]
# <class 'numpy.ndarray'>
# (3, 2)
# 6
# 2
# <U21
