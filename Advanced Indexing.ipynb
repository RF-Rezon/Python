# %%
import numpy as np

arr1 = np.array([10,20,30,60,30])
arr2 = np.array([[10,20,30],
                 [40,50,60]])

x = arr1[[1,-1]]
y = arr2[[0,1],[1,2]]

z = arr1[arr1 > 10]        # No for loop! 🔥
# print(z)

# for i in arr2:
#     for j in i:
#         print(j)     eivabe kora jay.....tobe....

arr3 = np.array([[10,20,30],
                 [40,50,60],
                [70,20,40],
                ])
for i in np.nditer(arr3):       # nditer diye kora valo. 2 step loop ekbare hoye jay. 
    print(i)
# Out:
# 10
# 20
# 30
# 40
# 50
# 60
# 70
# 20
# 40
