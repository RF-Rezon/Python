# %%
a = 10
x = a/0
print(x)

print("Next lines......")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 a = 10
# ----> 2 x = a/0
#       3 print(x)
#       5 print("Next lines......")
#
# ZeroDivisionError: division by zero

# %%
a = 10
try:
    x = a/0
except ZeroDivisionError:
    print("You cannot divide a number by 0")

print("Next lines......")

# Eivabe handle korle program ta crash korche na.
# Out:
# You cannot divide a number by 0
# Next lines......

# %%
try:
    file= open(".fileName/text.txt","r")
except FileNotFoundError as fe:
    print(fe)
else:
    print("Found")
finally:
    print("End.")
# Out:
# [Errno 2] No such file or directory: '.fileName/text.txt'
# End.

# %%
try:
    file= open("./text.txt","r")
except FileNotFoundError as fe:
    print(fe)
else:
    print("Found")
finally:
    print("End.")
# Out:
# Found
# End.

# %% [markdown]
# ## Specefic error jana na thakle ba checking er sujog na thakle ekbare universal way:

# %%
try:
    file= open(".fileName/text.txt","r")
except Exception as fe:           ## Use keyword "Exception"
    print(fe)
else:
    print("Found")
finally:
    print("End.")
# Out:
# [Errno 2] No such file or directory: '.fileName/text.txt'
# End.
