# %% [markdown]
# ## 1 Continuous-Discontinuous

# %% [markdown]
# List discontinuous. Er element gulo memoryr bivinno jaygay choriye cu=itiye thake. Location Continuous na. Scattered.

# %%
NdArray continuous. C++ er arrayr moto. Er element gulo memoryr ekta pointer theke suru hoye 4 byte 4 byte kore continuous akare thake.

# %% [markdown]
# ## 2 Same Type

# %%
List e ja mon cay tai rakha jay. Element gular type sobsomoy same na.

# %%
NdArray te elements sobsomoy same type hoy.

# %% [markdown]
# ## 3 Vectorization

# %%
NdArray r khetre, data continuous and same type obar karone Vectorization possible hoy. CPU te SIMD (Single Instruction Multiple Data)
use kora somvob hoy. Jodi NdArray r moddhe onkgula element thake, sobgulake ekta single instruction diye ekbare math operation korano jay.

# %%
Array te khetre Vectorization possible na. Ekhetre Array te jotogula element thake sobgula alada alada kore jog-biyog-gun hoy. Tai 
single instruction e kaj korte pare na.

# %% [markdown]
# ## Why best for AI/ML

# %%
Amader Linear Algebra, Math and Statistics lagbe Ai/ML er jonno. Egular prottektai Numpy diye khub valovabe operate korar sujog ase.
