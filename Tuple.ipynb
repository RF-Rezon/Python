# %%
a = (10,30,50,40,60,100)
b = ("Rezon", "Rocky", "Dabul", "Kabul", "Sabul")
c = (10, 10.23, "This is a list")
d = [10, 'Nothing', "Phone latest model"]
e= tuple(d)
print(type(e))
# Out:
# <class 'tuple'>

# %% [markdown]
# ## Access

# %%
x = (10, 10.23, "This is a list", 20, 30, 40, 50)

## index
print(x[2])
## slicing 
print(x[1:4])
# Out:
# This is a list
# (10.23, 'This is a list', 20)

# %% [markdown]
# ## Method

# %%
x = (10, 10.23, "This is a list", 20, 30, 40, 50, 10.23)
## count
print(x.count(10.23))
## index
print(x.index(10.23))
# Out:
# 2
# 1
